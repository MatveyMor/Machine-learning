# %% [markdown]
# ## Домашнее задание 1
#
# ### Матвей Морозов 676 гр.
# Используя геометрические интерпретации, решить следующие экстремальные задачи:
# Используя геометрические интерпретации, решить следующие экстремальные задачи:
# $\text{extr}\left(x_1^2 + 4x_2^2\right)$ при условии $\left|x_1\right|^\lambda + 2 \left|x_2\right|^\lambda \le 1, \;\; \lambda \neq 0$

# %% [markdown]
# # $\lambda > 0$

# %%
from matplotlib import pyplot
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

x1 = np.linspace(-4,4,1000) 
x2 = np.linspace (-2,2,1000)
x1, x2 = np.meshgrid(x1, x2)

lambd = [1,2,3,4]

# def target_points(x1,x2): #просто пройдемся по всем возможным точкам и выберем те, 
#                             #которые удовлетворяют нашему бюджетному множеству
#     a=[]
#     b=[]
#     z=[]
#     for i in range(1000):
#         for k in range(1000):   
#             if (np.abs(x1[i])**lam + np.abs (x2[k])**lam) <= 1:
#                 a=np.append(a,x1[i])
#                 b=np.append(b,x2[k])
#                 z=np.append(z,np.abs(x1[i])**lam + np.abs (x2[k])**lam)
#     return a, b, z

i=1

for lam in lambd:
    ax = fig.add_subplot(1, 4, i, projection='3d')
    
    z = np.where ((np.abs(x1)**lam + np.abs (x2)**lam)<=1, np.abs(x1)**lam + np.abs (x2)**lam, -10)

    z1 = x1**2 + 4*x2**2

    fig = pyplot.figure(figsize=[12, 5])
    ax = fig.gca(projection='3d')

    #ax.scatter(a1, a2, z, color = 'grey')
    surf = ax.plot_surface(x1, x2, z1)
    surf = ax.plot_surface(x1, x2, z, color = 'grey')
    ax.set_title('lam='+str(i))
    i=i+1

    pyplot.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

def target_points(x1,x2): #просто пройдемся по всем возможным точкам и выберем те, 
                            #которые удовлетворяют нашему бюджетному множеству
    a=[]
    b=[]
    z=[]
    for i in range(1000):
        for k in range(1000):   
            if (np.abs(x1[i])**lam + np.abs (x2[k])**lam) <= 1:
                a=np.append(a,x1[i])
                b=np.append(b,x2[k])
                z=np.append(z,np.abs(x1[i])**lam + np.abs (x2[k])**lam)
    return a, b, z


r = 1                 # radius

phi = np.linspace(0, 2*np.pi, 240)        # angle

r, phi = np.meshgrid(r, phi)              # computational grid

x1 = 2 * r * np.cos(phi)                         # parametrization
x2 = r * np.sin(phi)

lambd = [1,2,3,4]

fig, ax = plt.subplots(figsize=[18, 6])

i=1

for lam in lambd:
    plt.subplot (2,2,i)
    a = np.linspace(-4,4,1000) 
    b = np.linspace (-2,2,1000)
    a, b, z = target_points(a, b)
    plt.plot(x1,x2)
    plt.plot(a,b, color='grey')
    plt.legend(loc='best')
    plt.title('lam='+str(i))
    i=i+1
plt.show()

# %% [markdown]
# # $\lambda < 0$

# %%
from matplotlib import pyplot
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

x1 = np.linspace(-4,4,1000) 
x2 = np.linspace (-2,2,1000)
x1, x2 = np.meshgrid(x1, x2)

lambd = [-1,-2,-3,-4]

# def target_points(x1,x2): #просто пройдемся по всем возможным точкам и выберем те, 
#                             #которые удовлетворяют нашему бюджетному множеству
#     a=[]
#     b=[]
#     z=[]
#     for i in range(1000):
#         for k in range(1000):   
#             if (np.abs(x1[i])**lam + np.abs (x2[k])**lam) <= 1:
#                 a=np.append(a,x1[i])
#                 b=np.append(b,x2[k])
#                 z=np.append(z,np.abs(x1[i])**lam + np.abs (x2[k])**lam)
#     return a, b, z

i=1

for lam in lambd:
    ax = fig.add_subplot(1, 4, i, projection='3d')
    
    z = np.where ((np.abs(x1)**lam + np.abs (x2)**lam)<=1, np.abs(x1)**lam + np.abs (x2)**lam, -10)

    z1 = x1**2 + 4*x2**2

    fig = pyplot.figure(figsize=[12, 5])
    ax = fig.gca(projection='3d')

    #ax.scatter(a1, a2, z, color = 'grey')
    surf = ax.plot_surface(x1, x2, z1)
    surf = ax.plot_surface(x1, x2, z, color = 'grey')
    ax.set_title('lam=-'+str(i))
    i=i+1

    pyplot.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

def target_points(x1,x2): #просто пройдемся по всем возможным точкам и выберем те, 
                            #которые удовлетворяют нашему бюджетному множеству
    a=[]
    b=[]
    z=[]
    for i in range(1000):
        for k in range(1000):   
            if (np.abs(x1[i])**lam + np.abs (x2[k])**lam) <= 1:
                a=np.append(a,x1[i])
                b=np.append(b,x2[k])
                z=np.append(z,np.abs(x1[i])**lam + np.abs (x2[k])**lam)
    return a, b, z


r = 1                 # radius

phi = np.linspace(0, 2*np.pi, 240)        # angle

r, phi = np.meshgrid(r, phi)              # computational grid

x1 = 2 * r * np.cos(phi)                         # parametrization
x2 = r * np.sin(phi)

lambd = [-1,-2,-3,-4]

fig, ax = plt.subplots(figsize=[18, 6])

i=1

for lam in lambd:
    plt.subplot (2,2,i)
    a = np.linspace(-4,4,1000) 
    b = np.linspace (-2,2,1000)
    a, b, z = target_points(a, b)
    plt.plot(x1,x2)
    plt.plot(a,b, color='grey')
    plt.legend(loc='best')
    plt.title('lam=-'+str(i))
    i=i+1
plt.show()
